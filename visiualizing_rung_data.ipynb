# %%
import numpy as np
import scipy as sp
import os
from astropy.io import fits
import matplotlib.pyplot as plt

# %%
rung_fits_path = "/media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/"

files = os.listdir(rung_fits_path)
for file in files:
    print(file)
    try:
        hdul = fits.open(rung_fits_path + file)
        print(hdul.info())
        img = hdul['PRIMARY'].data
        plt.imshow(img)
        plt.show()
    except:
        pass
# Out:
# non_drizzled-noise_map-1.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled-noise_map-1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   (59, 59)   float64
# None
# ABCD.png
# non_drizzled-lens-image-1.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled-lens-image-1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (59, 59)   float64
# None
# drizzled_image
# non_drizzled-noise_map-8.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled-noise_map-8.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   (59, 59)   float64
# None
# non_drizzled_psf-3.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled_psf-3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (61, 61)   float64
# None
# non_drizzled_psf-5.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled_psf-5.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (61, 61)   float64
# None
# non_drizzled_psf-6.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled_psf-6.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (61, 61)   float64
# None
# non_drizzled-noise_map-5.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled-noise_map-5.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   (59, 59)   float64
# None
# non_drizzled-lens-image-3.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled-lens-image-3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (59, 59)   float64
# None
# non_drizzled-noise_map-3.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled-noise_map-3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   (59, 59)   float64
# None
# non_drizzled-noise_map-6.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled-noise_map-6.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   (59, 59)   float64
# None
# non_drizzled-noise_map-7.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled-noise_map-7.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   (59, 59)   float64
# None
# non_drizzled_psf-7.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled_psf-7.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (61, 61)   float64
# None
# non_drizzled-lens-image-2.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled-lens-image-2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (59, 59)   float64
# None
# non_drizzled-lens-image-6.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled-lens-image-6.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (59, 59)   float64
# None
# non_drizzled-noise_map-4.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled-noise_map-4.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   (59, 59)   float64
# None
# non_drizzled_psf-1.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled_psf-1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (61, 61)   float64
# None
# lens_info_for_Good_team.txt
# non_drizzled_psf-4.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled_psf-4.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (61, 61)   float64
# None
# non_drizzled-lens-image-8.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled-lens-image-8.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (59, 59)   float64
# None
# non_drizzled_psf-8.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled_psf-8.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (61, 61)   float64
# None
# non_drizzled-noise_map-2.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled-noise_map-2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   (59, 59)   float64
# None
# non_drizzled-lens-image-4.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled-lens-image-4.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (59, 59)   float64
# None
# non_drizzled-lens-image-7.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled-lens-image-7.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (59, 59)   float64
# None
# non_drizzled-lens-image-5.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled-lens-image-5.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (59, 59)   float64
# None
# non_drizzled_psf-2.fits
# Filename: /media/joshua/HDD_fun2/time_delay_challenge/rung0/code1/f160w-seed3/non_drizzled_psf-2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   (61, 61)   float64
# None
