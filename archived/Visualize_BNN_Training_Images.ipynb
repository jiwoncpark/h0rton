# %%
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import lenstronomy.Util.param_util as param_util
# %matplotlib inline

from utils.parser import Config
cfg = Config.fromfile('interim_config.py')

# %% [markdown]
# The training dataset generated from this config file lives here.

# %%
cfg.out_dir
# Out:
# 'out_data/train_interim_seed123'

# %%
meta = pd.read_csv(os.path.join(cfg.out_dir, 'metadata.csv'), index_col=None)
meta.iloc[3]
# Out:
# lens_mass_center_x    -9.112221e-08
# lens_mass_center_y    -2.165123e-08
# lens_mass_gamma        2.004022e+00
# lens_mass_theta_E      1.069378e+00
# lens_mass_e1          -6.789646e-02
# lens_mass_e2           1.303340e-02
# lens_mass_gamma_ext    1.241912e-01
# lens_mass_psi_ext      8.092711e-01
# src_light_amp          8.398155e+02
# src_light_center_x     4.119762e-06
# src_light_center_y     7.726644e-04
# src_light_n_sersic     3.080355e+00
# src_light_R_sersic     4.204591e-01
# src_light_e1          -3.421275e-01
# src_light_e2           1.489261e-02
# Name: 3, dtype: float64

# %%
for img_file in os.listdir(cfg.out_dir):
    if img_file.endswith('.npy'):
        img_path = os.path.join(cfg.out_dir, img_file)
        img = np.load(img_path)

        plt.imshow(img, norm=colors.LogNorm(), origin='lower', cmap='jet')
        plt.colorbar()
        plt.show()

# %%
import astropy.io.fits as pyfits

test_img_path = os.path.join('data', 'rung1', 'code1', 'f160w-seed105', 'drizzled_image', 'lens-image.fits')
test_img = pyfits.getdata(test_img_path)

plt.imshow(test_img, norm=colors.LogNorm(), origin='lower', cmap='jet')
plt.colorbar()
